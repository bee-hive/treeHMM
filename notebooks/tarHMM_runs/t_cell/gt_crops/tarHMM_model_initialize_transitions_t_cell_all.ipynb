# %% [markdown]
# ### Model dry run with t cells from all ground truth crops
# - use pretrained SAM3 tracks (have full cell type dict for these)

# %% [markdown]
# ### Generate model inputs

# %%
import pickle
import numpy as np

import zipfile
from io import BytesIO
import tifffile

import os

from pathlib import Path
import yaml

from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

import matplotlib.pyplot as plt

from jax import vmap
from functools import partial

# %% [markdown]
# ### Visualize emissions

# %%
emissions = np.load("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_emissions_array.npy")

# %%
reshaped_emissions = emissions.reshape(-1, emissions.shape[-1])  # [T*num_cells, num_features]
reshaped_emissions.shape, (50*528)
# Out:
# ((26400, 3), 26400)

# %%
for i in range(5):
    kmeans = KMeans(n_clusters=i+2, random_state=0).fit(reshaped_emissions)
    score = silhouette_score(reshaped_emissions, kmeans.labels_)
    print(f"Silhouette Score for {i+2} clusters: {score:.4f}")
# Out:
# Silhouette Score for 2 clusters: 0.8695
# Silhouette Score for 3 clusters: 0.7992
# Silhouette Score for 4 clusters: 0.7715
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 for i in range(5):
#       2     kmeans = KMeans(n_clusters=i+2, random_state=0).fit(reshaped_emissions)
# ----> 3     score = silhouette_score(reshaped_emissions, kmeans.labels_)
#       4     print(f"Silhouette Score for {i+2} clusters: {score:.4f}")
#
# File /gladstone/engelhardt/lab/jutran/software/miniforge3/envs/treeHMM_env/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File /gladstone/engelhardt/lab/jutran/software/miniforge3/envs/treeHMM_env/lib/python3.12/site-packages/sklearn/metrics/cluster/_unsupervised.py:146, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     144     else:
#     145         X, labels = X[indices], labels[indices]
# --> 146 return float(np.mean(silhouette_samples(X, labels, metric=metric, **kwds)))
#
# File /gladstone/engelhardt/lab/jutran/software/miniforge3/envs/treeHMM_env/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File /gladstone/engelhardt/lab/jutran/software/miniforge3/envs/treeHMM_env/lib/python3.12/site-packages/sklearn/metrics/cluster/_unsupervised.py:310, in silhouette_samples(X, labels, metric, **kwds)
#     306 kwds["metric"] = metric
#     307 reduce_func = functools.partial(
#     308     _silhouette_reduce, labels=labels, label_freqs=label_freqs
#     309 )
# --> 310 results = zip(*pairwise_distances_chunked(X, reduce_func=reduce_func, **kwds))
#     311 intra_clust_dists, inter_clust_dists = results
#     312 intra_clust_dists = np.concatenate(intra_clust_dists)
#
# File /gladstone/engelhardt/lab/jutran/software/miniforge3/envs/treeHMM_env/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:2264, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    2262 else:
#    2263     X_chunk = X[sl]
# -> 2264 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    2265 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    2266     metric, None
#    2267 ) is euclidean_distances:
#    2268     # zeroing diagonal, taking care of aliases of "euclidean",
#    2269     # i.e. "l2"
#    2270     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File /gladstone/engelhardt/lab/jutran/software/miniforge3/envs/treeHMM_env/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File /gladstone/engelhardt/lab/jutran/software/miniforge3/envs/treeHMM_env/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:2473, in pairwise_distances(X, Y, metric, n_jobs, ensure_all_finite, **kwds)
#    2470         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2471     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2473 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File /gladstone/engelhardt/lab/jutran/software/miniforge3/envs/treeHMM_env/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1969, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1966     Y = X
#    1968 if effective_n_jobs(n_jobs) == 1:
# -> 1969     return func(X, Y, **kwds)
#    1971 # enforce a threading backend to prevent data communication overhead
#    1972 fd = delayed(_transposed_dist_wrapper)
#
# File /gladstone/engelhardt/lab/jutran/software/miniforge3/envs/treeHMM_env/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File /gladstone/engelhardt/lab/jutran/software/miniforge3/envs/treeHMM_env/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:371, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     365     if Y_norm_squared.shape != (1, Y.shape[0]):
#     366         raise ValueError(
#     367             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     368             f"Y_norm_squared of shape {original_shape}."
#     369         )
# --> 371 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File /gladstone/engelhardt/lab/jutran/software/miniforge3/envs/treeHMM_env/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:411, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     408     distances += XX
#     409     distances += YY
# --> 411 xp_zero = xp.asarray(0, device=device_, dtype=distances.dtype)
#     412 distances = _modify_in_place_if_numpy(
#     413     xp, xp.maximum, distances, xp_zero, out=distances
#     414 )
#     416 # Ensure that distances between vectors and themselves are set to 0.0.
#     417 # This may not be the case due to floating point rounding errors.
#
# File /gladstone/engelhardt/lab/jutran/software/miniforge3/envs/treeHMM_env/lib/python3.12/site-packages/sklearn/externals/array_api_compat/numpy/_aliases.py:89, in asarray(obj, dtype, device, copy, **kwargs)
#      82     return True
#      85 # asarray also adds the copy keyword, which is not present in numpy 1.0.
#      86 # asarray() is different enough between numpy, cupy, and dask, the logic
#      87 # complicated enough that it's easier to define it separately for each module
#      88 # rather than trying to combine everything into one function in common/
# ---> 89 def asarray(
#      90     obj: Array | complex | NestedSequence[complex] | SupportsBufferProtocol,
#      91     /,
#      92     *,
#      93     dtype: DType | None = None,
#      94     device: Device | None = None,
#      95     copy: _Copy | None = None,
#      96     **kwargs: Any,
#      97 ) -> Array:
#      98     """
#      99     Array API compatibility wrapper for asarray().
#     100
#     101     See the corresponding documentation in the array library and/or the array API
#     102     specification for more details.
#     103     """
#     104     _helpers._check_device(np, device)
#
# KeyboardInterrupt:

# %% [markdown]
# do a version with 2 clusters and a version with 3 clusters

# %%
kmeans_2_clusters = KMeans(n_clusters=2, random_state=0).fit(reshaped_emissions)
kmeans_3_clusters = KMeans(n_clusters=3, random_state=0).fit(reshaped_emissions)

# %%
pca = PCA(n_components=2)
pca_embeddings = pca.fit_transform(reshaped_emissions)
print(pca.explained_variance_ratio_)
print(np.sum(pca.explained_variance_ratio_))
# Out:
# [0.8923079  0.06252795]
# 0.9548358532590845

# %%
colors_2_clusters = kmeans_2_clusters.labels_
colors_3_clusters = kmeans_3_clusters.labels_

fig, ax = plt.subplots(1, 2, figsize=(8, 6))

ax[0].scatter(pca_embeddings[:, 0], pca_embeddings[:, 1], c=colors_2_clusters, cmap='viridis')
ax[0].set_title("PCA of T Cell Emissions (2 Clusters)")

ax[1].scatter(pca_embeddings[:, 0], pca_embeddings[:, 1], c=colors_3_clusters, cmap='viridis')
ax[1].set_title("PCA of T Cell Emissions (3 Clusters)")
# Out:
# Text(0.5, 1.0, 'PCA of T Cell Emissions (3 Clusters)')

# %% [markdown]
# ### Initialize and run model

# %%
import sys
import os
import importlib

os.chdir("/gladstone/engelhardt/lab/jutran/lci/treeHMM")

import jax
import jax.numpy as jnp
import jax.random as jr
from jax.scipy.stats import multivariate_normal

from utils import generate_tree_hmm_data
from utils import visualize_lineage

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from dynamax.hidden_markov_model import LinearAutoregressiveHMM
from models.tarhmm import tARHMM
from dynamax.utils.plotting import gradient_cmap
from dynamax.utils.utils import random_rotation
#from dynamax.hidden_markov_model.models.tarhmm import tree_hmm_backward_filter
from typing import Callable, Optional
from dynamax.types import IntScalar, Float, Array

# module import version sanity check
hasattr(jax.interpreters.xla, 'pytype_aval_mappings')

from models.tarhmm import tree_hmm_two_filter_smoother
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
num_states = list(range(2, 15))
emission_dim = 3
results = []

for state in num_states:
    num_states = state
    num_lags = 1

    transition_matrix = jnp.eye(num_states) * 0.85 + (1 - jnp.eye(num_states)) * 0.075

    emissions = np.load("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_emissions_array.npy")
    #emissions = emissions[:,:, 1:]

    with open("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_data.pkl", "rb") as f:
        data = pickle.load(f)
    
    with open("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_crop_and_cell_id_to_col.pkl", "rb") as f:
        crop_and_cell_id_to_col = pickle.load(f)

    arhmm = tARHMM(num_states, emission_dim, num_lags=num_lags)
    params, props = arhmm.initialize(key=jr.PRNGKey(1), method="kmeans", emissions=emissions, transition_matrix = transition_matrix)
    inputs = vmap(arhmm.compute_inputs)(
        jnp.array(emissions),
        jnp.array(data["parent_indices"]),
        jnp.array(data["is_division_mask"]),
        jnp.array(data["is_new_root_mask"]),
        jnp.array(data["active_mask"]),
    )

    # TODO: maybe fix this???
    batched_emissions = emissions
    batched_inputs = inputs
    batched_parent_indices = data["parent_indices"]
    batched_is_division_mask = data["is_division_mask"]
    batched_active_mask = data["active_mask"]
    batched_is_new_root_mask = data["is_new_root_mask"]

    fitted_params, lps = arhmm.fit_em(params, props, batched_emissions, inputs=batched_inputs,
    parent_indices=batched_parent_indices,
    is_division_mask=batched_is_division_mask,
    active_mask=batched_active_mask,
    is_new_root_mask=batched_is_new_root_mask)

    results.append((np.mean(lps), lps))
# Out:
# <style>
#     progress { appearance: none; border: none; border-radius: 4px; width: 300px;
#         height: 20px; vertical-align: middle; background: #e0e0e0; }
#
#     progress::-webkit-progress-bar { background: #e0e0e0; border-radius: 4px; }
#     progress::-webkit-progress-value { background: #2196F3; border-radius: 4px; }
#     progress::-moz-progress-bar { background: #2196F3; border-radius: 4px; }
#
#     progress:not([value]) {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px); }
#
#     progress.progress-bar-interrupted::-webkit-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-webkit-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted { background: #F44336; }
#
#     table.fastprogress { border-collapse: collapse; margin: 1em 0; font-size: 0.9em; }
#     table.fastprogress th, table.fastprogress td { padding: 8px 12px; border: 1px solid #ddd; text-align: left; }
#     table.fastprogress thead tr { background: #f8f9fa; font-weight: bold; }
#     table.fastprogress tbody tr:nth-of-type(even) { background: #f8f9fa; }
# </style>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:02&lt;00:00]</div>

# %%
emissions.shape
# Out:
# (6, 50, 88, 3)

# %%
state_range = list(range(2, 15))
cmap = plt.cm.viridis
colors = [cmap(i / (len(state_range) - 1)) for i in range(len(state_range))]

fig, ax = plt.subplots(figsize=(10, 5))
for i, (mean_lp, lps) in enumerate(results[:len(state_range)]):
    n = state_range[i]
    ax.plot(lps, color=colors[i], label=f"{n} states (mean={mean_lp:.1f})")

ax.set_xlabel("EM iteration")
ax.set_ylabel("Marginal log prob.")
ax.set_title("EM log probabilities by number of states")
ax.legend(loc="lower right")
plt.tight_layout()
plt.show()

# %%
num_states = [5]

for state in num_states:
    num_states = state
    emission_dim = 3
    num_lags = 1

    transition_matrix = jnp.eye(state) * 0.85 + (1 - jnp.eye(state)) * 0.075

    emissions = np.load("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_emissions_array.npy")
    #emissions = emissions[:,:, 1:]

    with open("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_data.pkl", "rb") as f:
        data = pickle.load(f)
    
    with open("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_crop_and_cell_id_to_col.pkl", "rb") as f:
        crop_and_cell_id_to_col = pickle.load(f)

    arhmm = tARHMM(num_states, emission_dim, num_lags=num_lags)
    params, props = arhmm.initialize(key=jr.PRNGKey(1), method="kmeans", emissions=emissions, transition_matrix = transition_matrix)
    inputs = vmap(arhmm.compute_inputs)(
        jnp.array(emissions),
        jnp.array(data["parent_indices"]),
        jnp.array(data["is_division_mask"]),
        jnp.array(data["is_new_root_mask"]),
        jnp.array(data["active_mask"]),
    )

    # TODO: maybe fix this???
    batched_emissions = emissions
    batched_inputs = inputs
    batched_parent_indices = data["parent_indices"]
    batched_is_division_mask = data["is_division_mask"]
    batched_active_mask = data["active_mask"]
    batched_is_new_root_mask = data["is_new_root_mask"]

    fitted_params, lps = arhmm.fit_em(params, props, batched_emissions, inputs=batched_inputs,
    parent_indices=batched_parent_indices,
    is_division_mask=batched_is_division_mask,
    active_mask=batched_active_mask,
    is_new_root_mask=batched_is_new_root_mask)

    # Compute the posterior distribution of the latent states
    #input_fwd = arhmm._inference_args(params, emissions, inputs, data['parent_indices'], data['is_division_mask'], data['active_mask'],data['is_new_root_mask'])
    input_fwd = vmap(partial(arhmm._inference_args, fitted_params))(emissions, inputs, data['parent_indices'], data['is_division_mask'], data['active_mask'],data['is_new_root_mask'])
    posterior = vmap(tree_hmm_two_filter_smoother)(*input_fwd)

    # save state assignments
    state_assignments = jnp.argmax(posterior.smoothed_probs, axis=-1)  # (50, 110)

    data_output_dir = "/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/"
    np.save(os.path.join(data_output_dir, f"batched_state_assignments_{num_states}_states.npy"), state_assignments)
# Out:
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>

# %%
state_assignments.shape
# Out:
# (6, 50, 88)

# %%
# emissions[:,:, 1:]
# Out:
# (50, 326, 2)

# %% [markdown]
# ### Visualize outputs

# %%
# max_probs = jnp.max(posterior.smoothed_probs, axis=-1)  # (50, 326)

# fig, ax = plt.subplots(figsize=(12, 8))
# im = ax.imshow(max_probs.T, aspect="auto", interpolation="none", cmap="viridis", origin="upper", vmin=0, vmax=1)
# ax.set_xlabel("Time")
# ax.set_ylabel("Cell")
# ax.set_title("Max Smoothed Probability")
# cbar = plt.colorbar(im, ax=ax)
# cbar.set_label("Probability")
# plt.tight_layout()
# plt.show()

# %%
max_probs = jnp.max(posterior.smoothed_probs, axis=-1)  # (50, 326)

fig, ax = plt.subplots(figsize=(12, 8))
im = ax.imshow(max_probs[4].T, aspect="auto", interpolation="none", cmap="viridis", origin="upper", vmin=0, vmax=1)
ax.set_xlabel("Time")
ax.set_ylabel("Cell")
ax.set_title("Max Smoothed Probability")
cbar = plt.colorbar(im, ax=ax)
cbar.set_label("Probability")
plt.tight_layout()
plt.show()

# %%
well_idx = 0
masked_state_assignments = jnp.where(jnp.isnan(max_probs[well_idx].T), jnp.nan, state_assignments[well_idx].T)

fig, ax = plt.subplots(figsize=(12, 8))
im = ax.imshow(masked_state_assignments, aspect="auto", interpolation="none", cmap="viridis", origin="upper")
ax.set_xlabel("Time")
ax.set_ylabel("Cell")
ax.set_title("State Assignments (argmax of smoothed_probs)")
cbar = plt.colorbar(im, ax=ax, ticks=range(num_states))
cbar.set_label("State")
plt.tight_layout()
plt.show()

# %%
initial_transitions = params.transitions.transition_matrix
plt.imshow(initial_transitions, vmin=0, vmax=1, cmap="Greys")
plt.xlabel("next state")
plt.ylabel("current state")
plt.title("initial transition matrix")
plt.colorbar()

# %%
fitted_transitions = fitted_params.transitions.transition_matrix
plt.imshow(fitted_transitions, vmin=0, vmax=1, cmap="Greys")
plt.xlabel("next state")
plt.ylabel("current state")
plt.title("fitted transition matrix (with velocity)")
plt.colorbar()

# %%
max_probs = jnp.max(posterior.smoothed_probs, axis=-1)  # (50, 326)

fig, ax = plt.subplots(figsize=(12, 8))
im = ax.imshow(max_probs.T, aspect="auto", interpolation="none", cmap="viridis", origin="upper", vmin=0, vmax=1)
ax.set_xlabel("Time")
ax.set_ylabel("Cell")
ax.set_title("Max Smoothed Probability")
cbar = plt.colorbar(im, ax=ax)
cbar.set_label("Probability")
plt.tight_layout()
plt.show()

# %%
masked_state_assignments = jnp.where(jnp.isnan(max_probs.T), jnp.nan, state_assignments.T)

fig, ax = plt.subplots(figsize=(12, 8))
im = ax.imshow(masked_state_assignments, aspect="auto", interpolation="none", cmap="viridis", origin="upper")
ax.set_xlabel("Time")
ax.set_ylabel("Cell")
ax.set_title("State Assignments (argmax of smoothed_probs)")
cbar = plt.colorbar(im, ax=ax, ticks=range(num_states))
cbar.set_label("State")
plt.tight_layout()
plt.show()

# %%
fitted_transitions = fitted_params.transitions.transition_matrix
plt.imshow(fitted_transitions, vmin=0, vmax=1, cmap="Greys")
plt.xlabel("next state")
plt.ylabel("current state")
plt.title("fitted transition matrix")
plt.colorbar()

# %% [markdown]
# ### New Visualizations (04/20/2026 batching)

# %%
posterior.smoothed_probs.shape
# Out:
# (6, 50, 88, 3)

# %%
max_probs = jnp.max(posterior.smoothed_probs[0], axis=-1)  # (50, 326)

fig, ax = plt.subplots(figsize=(12, 8))
im = ax.imshow(max_probs.T, aspect="auto", interpolation="none", cmap="viridis", origin="upper", vmin=0, vmax=1)
ax.set_xlabel("Time")
ax.set_ylabel("Cell")
ax.set_title("Max Smoothed Probability")
cbar = plt.colorbar(im, ax=ax)
cbar.set_label("Probability")
plt.tight_layout()
plt.show()

# %%
masked_state_assignments = jnp.where(jnp.isnan(max_probs.T), jnp.nan, state_assignments[0].T)

fig, ax = plt.subplots(figsize=(12, 8))
im = ax.imshow(masked_state_assignments, aspect="auto", interpolation="none", cmap="viridis", origin="upper")
ax.set_xlabel("Time")
ax.set_ylabel("Cell")
ax.set_title("State Assignments (argmax of smoothed_probs)")
cbar = plt.colorbar(im, ax=ax, ticks=range(num_states))
cbar.set_label("State")
plt.tight_layout()
plt.show()

# %%
initial_transitions = params.transitions.transition_matrix
plt.imshow(initial_transitions, vmin=0, vmax=1, cmap="Greys")
plt.xlabel("next state")
plt.ylabel("current state")
plt.title("initial transition matrix")
plt.colorbar()

# %%
fitted_transitions = fitted_params.transitions.transition_matrix
plt.imshow(fitted_transitions, vmin=0, vmax=1, cmap="Greys")
plt.xlabel("next state")
plt.ylabel("current state")
plt.title("fitted transition matrix")
plt.colorbar()

# %% [markdown]
# ### run model on only one well

# %%
emissions = np.load("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_emissions_array.npy")
#emissions = emissions[:,:, 1:]

with open("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_data.pkl", "rb") as f:
    data = pickle.load(f)

with open("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_crop_and_cell_id_to_col.pkl", "rb") as f:
    crop_and_cell_id_to_col = pickle.load(f)

# %%
num_states = [3]

for state in num_states:
    num_states = state
    emission_dim = 3
    num_lags = 1

    transition_matrix = jnp.eye(3) * 0.85 + (1 - jnp.eye(3)) * 0.075

    emissions = np.load("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_emissions_array.npy")
    #emissions = emissions[:,:, 1:]

    with open("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_data.pkl", "rb") as f:
        data = pickle.load(f)
    
    with open("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_crop_and_cell_id_to_col.pkl", "rb") as f:
        crop_and_cell_id_to_col = pickle.load(f)

    arhmm = tARHMM(num_states, emission_dim, num_lags=num_lags)
    params, props = arhmm.initialize(key=jr.PRNGKey(1), method="kmeans", emissions=emissions, transition_matrix = transition_matrix)
    inputs = vmap(arhmm.compute_inputs)(
        jnp.array(emissions),
        jnp.array(data["parent_indices"]),
        jnp.array(data["is_division_mask"]),
        jnp.array(data["is_new_root_mask"]),
        jnp.array(data["active_mask"]),
    )

    # TODO: maybe fix this???
    batched_emissions = emissions[0]
    batched_inputs = inputs[0]
    batched_parent_indices = data["parent_indices"][0]
    batched_is_division_mask = data["is_division_mask"][0]
    batched_active_mask = data["active_mask"][0]
    batched_is_new_root_mask = data["is_new_root_mask"][0]

    fitted_params, lps = arhmm.fit_em(params, props, batched_emissions, inputs=batched_inputs,
    parent_indices=batched_parent_indices,
    is_division_mask=batched_is_division_mask,
    active_mask=batched_active_mask,
    is_new_root_mask=batched_is_new_root_mask)

    # Compute the posterior distribution of the latent states
    #input_fwd = arhmm._inference_args(params, emissions, inputs, data['parent_indices'], data['is_division_mask'], data['active_mask'],data['is_new_root_mask'])

    input_fwd = arhmm._inference_args(params, emissions[0], inputs[0], data['parent_indices'][0], data['is_division_mask'][0], data['active_mask'][0],data['is_new_root_mask'][0])
    posterior = tree_hmm_two_filter_smoother(*input_fwd)

    # save state assignments
    state_assignments = jnp.argmax(posterior.smoothed_probs, axis=-1)  # (50, 110)

    # data_output_dir = "/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/"
    # np.save(os.path.join(data_output_dir, f"batched_state_assignments_{num_states}_states.npy"), state_assignments)
# Out:
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:02&lt;00:00]</div>

# %%
state_assignments.shape
# Out:
# (50, 88)

# %%
max_probs = jnp.max(posterior.smoothed_probs, axis=-1)  # (50, 326)

fig, ax = plt.subplots(figsize=(12, 8))
im = ax.imshow(max_probs.T, aspect="auto", interpolation="none", cmap="viridis", origin="upper", vmin=0, vmax=1)
ax.set_xlabel("Time")
ax.set_ylabel("Cell")
ax.set_title("Max Smoothed Probability")
cbar = plt.colorbar(im, ax=ax)
cbar.set_label("Probability")
plt.tight_layout()
plt.show()

# %%
masked_state_assignments = jnp.where(jnp.isnan(max_probs.T), jnp.nan, state_assignments.T)

fig, ax = plt.subplots(figsize=(12, 8))
im = ax.imshow(masked_state_assignments, aspect="auto", interpolation="none", cmap="viridis", origin="upper")
ax.set_xlabel("Time")
ax.set_ylabel("Cell")
ax.set_title("State Assignments (argmax of smoothed_probs)")
cbar = plt.colorbar(im, ax=ax, ticks=range(num_states))
cbar.set_label("State")
plt.tight_layout()
plt.show()

# %%
fitted_transitions = fitted_params.transitions.transition_matrix
plt.imshow(fitted_transitions, vmin=0, vmax=1, cmap="Greys")
plt.xlabel("next state")
plt.ylabel("current state")
plt.title("fitted transition matrix (with velocity)")
plt.colorbar()

# %% [markdown]
# ### try getting all the lps

# %%
import sys
import os
import importlib

os.chdir("/gladstone/engelhardt/lab/jutran/lci/treeHMM")

import jax
import jax.numpy as jnp
import jax.random as jr
from jax.scipy.stats import multivariate_normal

from utils import generate_tree_hmm_data
from utils import visualize_lineage

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from dynamax.hidden_markov_model import LinearAutoregressiveHMM
from models.tarhmm import tARHMM
from dynamax.utils.plotting import gradient_cmap
from dynamax.utils.utils import random_rotation
#from dynamax.hidden_markov_model.models.tarhmm import tree_hmm_backward_filter
from typing import Callable, Optional
from dynamax.types import IntScalar, Float, Array

# module import version sanity check
hasattr(jax.interpreters.xla, 'pytype_aval_mappings')

from models.tarhmm import tree_hmm_two_filter_smoother

# %%
num_states = list(range(2, 10))
results = []

for state in num_states:
    num_states = state
    emission_dim = 3
    num_lags = 1

    transition_matrix = jnp.eye(num_states) * 0.85 + (1 - jnp.eye(num_states)) * 0.075

    emissions = np.load("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_emissions_array.npy")
    #emissions = emissions[:,:, 1:]

    with open("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_data.pkl", "rb") as f:
        data = pickle.load(f)
    
    with open("/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/batched_crop_and_cell_id_to_col.pkl", "rb") as f:
        crop_and_cell_id_to_col = pickle.load(f)

    arhmm = tARHMM(num_states, emission_dim, num_lags=num_lags)
    params, props = arhmm.initialize(key=jr.PRNGKey(1), method="kmeans", emissions=emissions, transition_matrix = transition_matrix)
    inputs = vmap(arhmm.compute_inputs)(
        jnp.array(emissions),
        jnp.array(data["parent_indices"]),
        jnp.array(data["is_division_mask"]),
        jnp.array(data["is_new_root_mask"]),
        jnp.array(data["active_mask"]),
    )

    # TODO: maybe fix this???
    batched_emissions = emissions
    batched_inputs = inputs
    batched_parent_indices = data["parent_indices"]
    batched_is_division_mask = data["is_division_mask"]
    batched_active_mask = data["active_mask"]
    batched_is_new_root_mask = data["is_new_root_mask"]

    fitted_params, lps = arhmm.fit_em(params, props, batched_emissions, inputs=batched_inputs,
    parent_indices=batched_parent_indices,
    is_division_mask=batched_is_division_mask,
    active_mask=batched_active_mask,
    is_new_root_mask=batched_is_new_root_mask)

    results.append((np.mean(lps), lps))

    # # Compute the posterior distribution of the latent states
    # #input_fwd = arhmm._inference_args(params, emissions, inputs, data['parent_indices'], data['is_division_mask'], data['active_mask'],data['is_new_root_mask'])

    # input_fwd = arhmm._inference_args(params, emissions[0], inputs[0], data['parent_indices'][0], data['is_division_mask'][0], data['active_mask'][0],data['is_new_root_mask'][0])
    # posterior = tree_hmm_two_filter_smoother(*input_fwd)

    # # save state assignments
    # state_assignments = jnp.argmax(posterior.smoothed_probs, axis=-1)  # (50, 110)

    # # data_output_dir = "/gladstone/engelhardt/lab/jutran/lci/treeHMM/notebooks/data/all_gt_crops_pretrained_SAM3/"
    # # np.save(os.path.join(data_output_dir, f"batched_state_assignments_{num_states}_states.npy"), state_assignments)
# Out:
# <style>
#     progress { appearance: none; border: none; border-radius: 4px; width: 300px;
#         height: 20px; vertical-align: middle; background: #e0e0e0; }
#
#     progress::-webkit-progress-bar { background: #e0e0e0; border-radius: 4px; }
#     progress::-webkit-progress-value { background: #2196F3; border-radius: 4px; }
#     progress::-moz-progress-bar { background: #2196F3; border-radius: 4px; }
#
#     progress:not([value]) {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px); }
#
#     progress.progress-bar-interrupted::-webkit-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-webkit-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted { background: #F44336; }
#
#     table.fastprogress { border-collapse: collapse; margin: 1em 0; font-size: 0.9em; }
#     table.fastprogress th, table.fastprogress td { padding: 8px 12px; border: 1px solid #ddd; text-align: left; }
#     table.fastprogress thead tr { background: #f8f9fa; font-weight: bold; }
#     table.fastprogress tbody tr:nth-of-type(even) { background: #f8f9fa; }
# </style>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>
# <div><progress max="50" value="50"></progress> 100.00% [50/50 00:01&lt;00:00]</div>

# %%
state_range = list(range(2, 10))
cmap = plt.cm.viridis
colors = [cmap(i / (len(state_range) - 1)) for i in range(len(state_range))]

fig, ax = plt.subplots(figsize=(10, 5))
for i, (mean_lp, lps) in enumerate(results):
    n = state_range[i]
    ax.plot(lps, color=colors[i], label=f"{n} states (mean={mean_lp:.1f})")

ax.set_xlabel("EM iteration")
ax.set_ylabel("Marginal log prob.(?)")
ax.set_title("EM log probabilities(?) by number of states")
ax.legend(loc="lower right")
plt.tight_layout()
plt.show()

# %%
state_range = list(range(2, 10))
cmap = plt.cm.viridis
colors = [cmap(i / (len(state_range) - 1)) for i in range(len(state_range))]

fig, ax = plt.subplots(figsize=(10, 5))
for i, (mean_lp, lps) in enumerate(results):
    n = state_range[i]
    ax.plot(lps, color=colors[i], label=f"{n} states (mean={mean_lp:.1f})")

ax.set_xlabel("EM iteration")
ax.set_ylabel("Marginal log prob.(?)")
ax.set_title("EM log probabilities(?) by number of states")
ax.legend(loc="lower right")
plt.tight_layout()
plt.show()
